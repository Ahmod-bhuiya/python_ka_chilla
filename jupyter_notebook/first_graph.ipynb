# %%
## barplots
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)

titanic=sns.load_dataset("titanic")
sns.catplot(x="sex",y="survived",hue="class",kind="bar",data=titanic)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# sns.set_theme(style="ticks",color_codes=True)
p=sns.load_dataset("titanic")
sns.barplot(x="sex",y="survived",hue="who",data=p,order=["female","male"],color="blue", errorbar= None,palette="pastel",)
plt.title("statistic")
# Out:
# Text(0.5, 1.0, 'statistic')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
a=sns.load_dataset("titanic")
sns.barplot(x="sex",y="survived",data=a,
            linewidth=2,facecolor=(0,0,0,0),err_kws={'color': '.5'},edgecolor="0")
plt.title("statics")
# Out:
# Text(0.5, 1.0, 'statics')

# %%
## countplots
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)

titanic=sns.load_dataset("titanic")
p1=sns.countplot(x="sex",data=titanic,hue="class")
p1.set_title("plot forcounting")
# Out:
# Text(0.5, 1.0, 'plot forcounting')

# %%
##scatter plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks",color_codes=True)

titanic=sns.load_dataset("titanic")
g=sns.FacetGrid(titanic,row="sex",hue="alone")
g=(g.map(plt.scatter,"age","fare").add_legend())

# %% [markdown]
#  ## import libraries
# - **pandas**
# - **numpy**
# - **scipy**
# - **matplotlib**

# %%
##lineplots
import seaborn as sns
import matplotlib.pyplot as plt
p=sns.load_dataset("iris")
sns.lineplot(x="sepal_width",y="petal_length",data=p,)
plt.title("statistic")
# Out:
# Text(0.5, 1.0, 'statistic')

# %% [markdown]
# ## style
# - dark
# - darkgrid
# - white
# - whitegrid
# - ticks

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark",color_codes=True)
p=sns.load_dataset("iris")
sns.lineplot(x="sepal_width",y="petal_length",data=p,)
plt.title("statistic")
plt.xlim(0)
plt.ylim(0)
# Out:
# (0.0, 6.308000000000001)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="dark",color_codes=True)
p=sns.load_dataset("iris")
plt.figure(figsize=(5,2))
sns.lineplot(x="sepal_width",y="petal_length",data=p,)
plt.title("statistic")
# Out:
# Text(0.5, 1.0, 'statistic')

# %%
# boxplot
import seaborn as sns
a=sns.load_dataset("titanic")
sns.set(style='whitegrid')
sns.boxplot(x="class",y="fare",data=a)
# Out:
# <Axes: xlabel='class', ylabel='fare'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
a=sns.load_dataset("tips")
a.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns
a=sns.load_dataset("tips")
sns.boxplot(x=a["day"],y=a["tip"],hue=a["smoker"],palette="pastel")
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
a=sns.load_dataset("tips")
sns.boxplot(x="sex",y="tip",data=a,showmeans=True,meanprops={'marker':'*','markersize':'12','markeredgecolor':'white'})
plt.xlabel("your sex")
plt.title("statistics",weight="bold",size=20)
# Out:
# Text(0.5, 1.0, 'statistics')

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
d=sns.load_dataset("titanic")
# d.head()
p=sns.color_palette("rocket_r")
sns.relplot(data=d,x="sex",y="pclass",)

# %%
pip install
